# %%
#Control statement 
#code1 
#if statement & if_else 

num = 1

if(num >= 1):
    print('Number is positive')
else:
    print('This line will print always')

# # if -1 and 0:
# # 0, None, -ve, +ve
# Out:
# Number is positive

# %%
#if...elif..else Statement
num = 0

if(num > 0):
     print('Positive')
elif(num == 0):
     print('ZERO')
else:
     print('Negative')
# Out:
# ZERO

# %%
# # Try 90, 78, 50, 9999
grade = 90

if grade >= 90 and grade<=100:
     print("A grade")

elif grade >=80 and grade<=90:
    print("B grade")
elif grade >=70:
    print("C grade")
elif grade >= 65:
    print("D grade")
else:
     print("Failing grade")
# Out:
# A grade

# %%
#Nested if - else statement 
num = 0 
if num>= 0:
    if num == 0:
        print("zera")
    else:
        print("positive")
else:
    print("nehgative")
# Out:
# zera

# %%
 grade = 60

if grade >= 65 and grade<=100:
    print("Passing grade of:", end = ' ')
    if grade >= 90:
         print("A")
    elif grade >=80:
         print("B")
    elif grade >=70:
         print("C")
    elif grade >= 65:
         print("D")
elif grade>100:
         print('Invalid Input')
else:
         print("failing grade")
# Out:
# failing grade

# %% [markdown]
# ![image.png](attachment:9e7a7108-bcb7-4e15-b929-e46994c5947c.png)![image.png](attachment:8ac73f89-2027-4727-89b4-6b0af827d22a.png)
